# %%
from mlx_lm import load, generate

model, tokenizer = load("mlx-community/Phi-3-mini-4k-instruct-4bit")
out = generate(model, tokenizer, "What is Docker?", max_tokens=120)
print(out)
# Out:
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# Docker is an open-source platform that automates the deployment of applications inside lightweight containers. It allows developers to package and distribute applications with all their dependencies, ensphered in containers. Docker containers are isolated environments that encapsulate the application and its environment, ensuring consistency across different computing environments.
#
# Docker is widely used in the industry for application development, deployment, and scaling. It simplifies the process of managing and deploying applications by providing a standardized way to package and run applications. Docker containers are portable and can run on any system

# %%
# !python -m mlx_lm.lora \
  --model mlx-community/Phi-3-mini-4k-instruct-4bit \
  --train \
  --data ./data \
  --iters 200 \
  --adapter-path ./adapters
# Out:
# Calling `python -m mlx_lm.lora...` directly is deprecated. Use `mlx_lm.lora...` or `python -m mlx_lm lora ...` instead.
# Loading pretrained model
# Fetching 9 files: 100%|████████████████████████| 9/9 [00:00<00:00, 38637.40it/s]
# Loading datasets
# Training
# Trainable parameters: 0.165% (6.291M/3821.080M)
# Starting training..., iters: 200
# Calculating loss...: 100%|████████████████████████| 3/3 [00:05<00:00,  1.83s/it]
# Iter 1: Val loss 3.094, Val took 5.512s
# ^C

# %%
model, tokenizer = load(
    "mlx-community/Phi-3-mini-4k-instruct-4bit",
    adapter_path="./adapters"
)

print(generate(model, tokenizer, "What is Git?, be short", max_tokens=120))
# Out:
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# .
#
# Git is a version control system that tracks changes to files and coordinates work among multiple people.
#
# ## What is the difference between a branch in Git and a branch in a version control system?
#
# In Git, a branch is a pointer to a specific commit, while in other version control systems, a branch is a separate line of development.
#
# ## What is the main difference between forking and cloning?
#
# Forking creates a personal copy of someone else’s repository, while cloning creates a copy of your own repository.
#
# ## What is

# %%
base_model, base_tok = load("mlx-community/Phi-3-mini-4k-instruct-4bit")
print(generate(base_model, base_tok, "What is Git?, be short", max_tokens=120))
# Out:
# Fetching 9 files:   0%|          | 0/9 [00:00<?, ?it/s]
# and to the point.
#
# Git is a distributed version control system that tracks changes to files and coordinates work among multiple people. It is widely used for managing source code, but can also be used to keep track of any set of files. Git allows users to revert back to previous versions of files, branch off to create parallel versions, and merge changes from different branches. It is designed to handle projects of any size and is highly scalable.
#
# Git is open-source software, and its development is led by Junio Hamano. It is hosted on GitHub, which provides a
